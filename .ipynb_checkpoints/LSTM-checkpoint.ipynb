# %%
# pip install --upgrade yfinance

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import pandas_datareader as data

# %%
# start = '2015-01-01'
# end = '2024-12-31'
# # df = Data.DataReader('AAPL', 'yahoo',start,end)

# %%
# import yfinance as yf
# import pandas as pd

# # Define date range
# start = '2015-01-01'
# end = '2024-12-31'

# # Download AAPL data
# df = yf.download('AAPL', start=start, end=end)

# # Display the first few rows
# print(df.head())

# %%
ticker_obj = yf.Ticker('AAPL')
df = ticker_obj.history(start='2010-01-01', end='2019-12-31')

df.head(3)
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 2010-01-04 00:00:00-05:00  6.422875  6.455075  6.391277  6.440330  493729600
# 2010-01-05 00:00:00-05:00  6.458087  6.487879  6.417460  6.451466  601904800
# 2010-01-06 00:00:00-05:00  6.451466  6.477046  6.342226  6.348847  552160000
#
#                            Dividends  Stock Splits
# Date
# 2010-01-04 00:00:00-05:00        0.0           0.0
# 2010-01-05 00:00:00-05:00        0.0           0.0
# 2010-01-06 00:00:00-05:00        0.0           0.0

# %%
df.tail()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2019-12-23 00:00:00-05:00  67.917550  68.818178  67.878812  68.757652
# 2019-12-24 00:00:00-05:00  68.924716  68.973140  68.496193  68.823029
# 2019-12-26 00:00:00-05:00  68.956196  70.205456  68.927145  70.188507
# 2019-12-27 00:00:00-05:00  70.481460  71.171459  69.755147  70.161880
# 2019-12-30 00:00:00-05:00  70.079551  70.861551  69.053030  70.578285
#
#                               Volume  Dividends  Stock Splits
# Date
# 2019-12-23 00:00:00-05:00   98572000        0.0           0.0
# 2019-12-24 00:00:00-05:00   48478800        0.0           0.0
# 2019-12-26 00:00:00-05:00   93121200        0.0           0.0
# 2019-12-27 00:00:00-05:00  146266000        0.0           0.0
# 2019-12-30 00:00:00-05:00  144114400        0.0           0.0

# %%
# df = df.drop(df['Date'], axis =1)
df = df.reset_index()
df.head()
# Out:
#    index                      Date      Open      High       Low     Close  \
# 0      0 2010-01-04 00:00:00-05:00  6.422875  6.455075  6.391277  6.440330
# 1      1 2010-01-05 00:00:00-05:00  6.458087  6.487879  6.417460  6.451466
# 2      2 2010-01-06 00:00:00-05:00  6.451466  6.477046  6.342226  6.348847
# 3      3 2010-01-07 00:00:00-05:00  6.372320  6.379844  6.291067  6.337110
# 4      4 2010-01-08 00:00:00-05:00  6.328684  6.379844  6.291369  6.379241
#
#       Volume  Dividends  Stock Splits
# 0  493729600        0.0           0.0
# 1  601904800        0.0           0.0
# 2  552160000        0.0           0.0
# 3  477131200        0.0           0.0
# 4  447610800        0.0           0.0

# %%
# df = df.drop(['index'], axis=1)
df = df.drop(['Date','Dividends','Stock Splits'], axis=1)
df.head()
# Out:
#        Open      High       Low     Close     Volume
# 0  6.422875  6.455075  6.391277  6.440330  493729600
# 1  6.458087  6.487879  6.417460  6.451466  601904800
# 2  6.451466  6.477046  6.342226  6.348847  552160000
# 3  6.372320  6.379844  6.291067  6.337110  477131200
# 4  6.328684  6.379844  6.291369  6.379241  447610800

# %%
plt.plot(df.Close)

# %%
ma100 = df.Close.rolling(100).mean()
ma100
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 2510    57.212838
# 2511    57.410469
# 2512    57.647437
# 2513    57.875338
# 2514    58.102497
# Name: Close, Length: 2515, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.plot(ma100, 'r')
plt.plot(df.Close)

# %%
ma200 = df.Close.rolling(200).mean()

# %%
plt.figure(figsize=(12,6))
plt.plot(df.Close)
plt.plot(ma100, 'r')
plt.plot(ma200 , 'g')

# %%
df.shape
# Out:
# (2515, 5)

# %%
data_training = pd.DataFrame(df['Close'][0:int(len(df)*0.7)])
data_testing = pd.DataFrame(df['Close'][int(len(df)*0.7):len(df)])

# %%
print(data_training.head())
print(data_testing.head())
# Out:
#       Close
# 0  6.440330
# 1  6.451466
# 2  6.348847
# 3  6.337110
# 4  6.379241
#           Close
# 1760  26.996561
# 1761  26.786110
# 1762  26.862425
# 1763  26.832359
# 1764  26.968815

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range= (0,1))

# %%
data_training_array = scaler.fit_transform(data_training)

# %%
data_training_array
# Out:
# array([[0.02759996],
#        [0.02806507],
#        [0.02377927],
#        ...,
#        [0.8840842 ],
#        [0.89123165],
#        [0.88640219]])

# %%
data_training_array.shape
# Out:
# (1760, 1)

# %%
x_train = []
y_train= []

for i in range(100,data_training_array.shape[0]):
    x_train.append(data_training_array[i-100 : i])
    y_train.append(data_training_array[i,0])

# %%
x_train,y_train = np.array(x_train), np.array(y_train)

# %%
x_train.shape
# Out:
# (1660, 100, 1)

# %% [raw]
# pip install --upgrade numpy==1.23.5

# %%
from keras.layers import Dense, Dropout, LSTM
from keras.models import Sequential

# %%
model = Sequential()
model.add(LSTM(units= 50, activation= 'relu',return_sequences=True, 
              input_shape = (x_train.shape[1],1)))
model. add (Dropout (0.2))

model.add(LSTM(units= 60, activation= 'relu',return_sequences=True))
model. add (Dropout (0.3))


model.add(LSTM(units= 60, activation= 'relu',return_sequences=True))
model. add (Dropout (0.4))

model.add(LSTM(units= 120, activation= 'relu',return_sequences=True))
model. add (Dropout (0.5))

model.add(Dense(units =1))
# Out:
# /Users/yashshah/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100, 50)        │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 100, 50)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 100, 60)        │        26,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 100, 60)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 100, 60)        │        29,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 100, 60)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 100, 120)       │        86,880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 100, 120)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 100, 1)         │           121 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 153,081 (597.97 KB)
#  Trainable params: 153,081 (597.97 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(x_train,y_train,epochs=50)
# Out:
# Epoch 1/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 89ms/step - loss: 0.1652
# Epoch 2/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 0.0816
# Epoch 3/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - loss: 0.0810
# Epoch 4/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - loss: 0.0736
# Epoch 5/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - loss: 0.0746
# Epoch 6/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - loss: 0.0765
# Epoch 7/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - loss: 0.0721
# Epoch 8/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - loss: 0.0734
# Epoch 9/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - loss: 0.0748
# Epoch 10/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 0.0728
# Epoch 11/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - loss: 0.0746
# Epoch 12/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - loss: 0.0703
# Epoch 13/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - loss: 0.0721
# Epoch 14/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - loss: 0.0689
# Epoch 15/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - loss: 0.0736
# Epoch 16/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - loss: 0.0717
# Epoch 17/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - loss: 0.0752
# Epoch 18/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - loss: 0.0704
# Epoch 19/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - loss: 0.0711
# Epoch 20/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - loss: 0.0692
# Epoch 21/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - loss: 0.0699
# Epoch 22/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 0.0682
# Epoch 23/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - loss: 0.0675
# Epoch 24/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - loss: 0.0687
# Epoch 25/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - loss: 0.0707
# Epoch 26/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - loss: 0.0710
# Epoch 27/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - loss: 0.0701
# Epoch 28/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - loss: 0.0726
# Epoch 29/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - loss: 0.0738
# Epoch 30/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - loss: 0.0708
# Epoch 31/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - loss: 0.0720
# Epoch 32/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - loss: 0.0694
# Epoch 33/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 106ms/step - loss: 0.0709
# Epoch 34/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - loss: 0.0699
# Epoch 35/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - loss: 0.0711
# Epoch 36/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - loss: 0.0682
# Epoch 37/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - loss: 0.0692
# Epoch 38/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 0.0703
# Epoch 39/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - loss: 0.0689
# Epoch 40/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - loss: 0.0694
# Epoch 41/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 0.0717
# Epoch 42/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 0.0697
# Epoch 43/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 0.0683
# Epoch 44/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - loss: 0.0695
# Epoch 45/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - loss: 0.0704
# Epoch 46/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - loss: 0.0680
# Epoch 47/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - loss: 0.0679
# Epoch 48/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - loss: 0.0681
# Epoch 49/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - loss: 0.0698
# Epoch 50/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - loss: 0.0686

# %%
model.save('keras_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
data_testing.head()
# Out:
#           Close
# 1760  26.996561
# 1761  26.786110
# 1762  26.862425
# 1763  26.832359
# 1764  26.968815

# %%
data_training.tail()
# Out:
#           Close
# 1755  27.072889
# 1756  26.894810
# 1757  26.948002
# 1758  27.119141
# 1759  27.003504

# %%
past_100_days = data_training.tail()

# %%
 final_df = past_100_days.append(data_testing,ignore_index = True)
# Out:
# /var/folders/g8/kpw7958101scbg6jc_dw_ggr0000gn/T/ipykernel_46469/2767363129.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = past_100_days.append(data_testing,ignore_index = True)

# %%
 final_df.head()
# Out:
#        Close
# 0  27.072889
# 1  26.894810
# 2  26.948002
# 3  27.119141
# 4  27.003504

# %%
input_data = scaler.fit_transform(final_df)

# %%
input_data
input_data.shape
# Out:
# (760, 1)

# %%
x_test = []
y_test = []

for i in range(100,input_data.shape[0]):
    x_test.append(input_data[i-100 : i])
    y_test.append(input_data[i,0])

# %%
x_test,y_test = np.array(x_test), np.array(y_test)
print(x_test.shape)
print(y_test.shape)
# Out:
# (660, 100, 1)
# (660,)
